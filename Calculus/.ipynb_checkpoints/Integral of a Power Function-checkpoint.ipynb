# %% [markdown]
# The integral of a power function generalizes the antiderivative for monomials. This rule is fundamental in integral calculus and applied in ML for cost function analysis.
# ![image.png](attachment:196e0bc9-02f4-4b6c-ad80-305ab5f25600.png)
# ![image.png](attachment:bac5772f-12e9-45c7-93e0-bdf8fae21a18.png).

# %%
import sympy as sp

# Define the symbol
x = sp.Symbol('x')

# Define the function
f = x**3

# Integrate
integral = sp.integrate(f, x)

# Show result
print("Integral of x^3:", integral)
# Out:
# Integral of x^3: x**4/4

# %%
f = x**-2
integral = sp.integrate(f, x)
print("Integral of x^(-2):", integral)
# Out:
# Integral of x^(-2): -1/x
